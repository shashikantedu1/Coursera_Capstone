# %% [markdown]
# # Capstone Project – The Battle of Neighborhoods, Toronto

# %% [markdown]
# ## 1. Introduction:

# %% [markdown]
# This project will mainly focus on making people lives better by helping them exploring nearby ameneties. This will have significant impact on the lifestyle of people. They can choose wisely, act smartly , take correct decisions and overall user experience will improve.
#
# One of the major problem faced by people while migrating to different cities is choosing the neighbourhood in that particular city. Few factors like comfort, convenience, and saftey can play major role in choosing the neighborhood.
#
# There can be numerous reasons for a person to move to new location. This project will help people to get acquinted with the neighborhood  and preplan the arrangements before relocating to new area.

# %% [markdown]
# ## 2. Data Section:

# %% [markdown]
# Dataset used for this project:
#
# * Data for fetching postal codes of Canada: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# * Latitude and Longitude details from geo spatial csv : http://cocl.us/Geospatial_data
# * Foursquare API Data
#
# We will need data about different venues in different neighborhoods of that specific borough. In order to gain that information we will use "Foursquare" locational information. Foursquare is a location data provider with information about all manner of venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. As such, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
# After finding the list of neighborhoods, we then connect to the Foursquare API to gather information about venues inside each and every neighborhood. For each neighborhood, we have chosen the radius to be 500 meter.
#
# Below details will be fetched for using Foursquare API:
#
# * Neighborhood
# * Neighborhood Latitude
# * Neighborhood Longitude
# * Venue
# * Name of the venue
# * Venue Latitude
# * Venue Longitude
# * Venue Category

# %% [markdown]
# ## 3. Methodology Section

# %% [markdown]
# Clustering and Segmentation Approach:
#
# Localities comparision on the basis of available venues in the neighborhood will be of very much help to wide variety of audience.
#
# Approach was to form clusters in Toronto city on the basis of neighborhood, most frequent searched or accessed venues. Segmented localities on the basis of available ameneties will help people to identify and take decisions to meet their requirements.
#
# In order to do that, we need to cluster data which is a form of unsupervised machine learning: k-means clustering algorithm.
#
# Using K-Means Clustering Approach

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the above image, neighborhoods have been classfied into different cluster on the basis of similarities of the most common venues available in the localities.

# %% [markdown]
# Work Flow:
#
# Using credentials of Foursquare API features of near-by places of the neighborhoods would be mined. Due to http request limitations the number of places per neighborhood parameter would reasonably be set to 100 and the radius parameter would be set to 500.

# %% [markdown]
# ## 4. Results Section

# %% [markdown]
# ### Representation of Clusters in Toronto city

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Location:

# %% [markdown]
# Toronto is a popular destination for new immigrants in Canada to reside. As a result, it is one of the most diverse and multicultural areas in Canada. Toronto continues to welcome the most immigrants among Canadian cities by a very wide margin. It attracted nearly 118,000 immigrants last year or 35 per cent of Canada's newcomer total.

# %% [markdown]
# ### Foursquare API:

# %% [markdown]
# This project have used Four-square API as its prime data gathering source as it has a database of millions of places, especially their places API which provides the ability to perform location search, location sharing and details about a business.

# %% [markdown]
# ## 5. Discussion Section

# %% [markdown]
# Problem tried to solve through this project:
#
# The main objective of this case study is to suggest various options of localities on the basis of neighborhood, venues, amenities to wide vareity of people who are migrating to Toronto city to open a business, immigrants, people on business trip etc. Connectivity to the airport, bus stand, city center, markets and other daily needs things nearby.

# %% [markdown]
# ## 6. Conclusion Section

# %% [markdown]
# In this project, using k-means cluster algorithm the neighborhoods have been segmented into 5 different clusters for different lattitude and logitude from dataset, which have very-similar neighborhoods around them.
# The mapping with Folium is a very powerful technique to consolidate information and make the analysis and decision better with confidence.

# %% [markdown]
# Libraries used in the Project:
#
#     Pandas: For creating and manipulating dataframes.
#     Folium: Python visualization library to visualize the neighborhoods cluster distribution
#     Scikit Learn: For importing k-means clustering.
#     JSON: Library to handle JSON files.
#     XML: To separate data from presentation and XML stores data in plain text format.
#     Geocoder: To retrieve Location Data.
#     Beautiful Soup and Requests: To scrap and library to handle http requests.
#     Matplotlib: Python Plotting Module
